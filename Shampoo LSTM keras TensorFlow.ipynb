# %%
# load and plot dataset
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
# load dataset
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')
# series = read_csv('shampoo-sales.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
series = read_csv('/Users/lorinfields/Downloads/Shampoo-sales.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)

# summarize first few rows
print(series.head())
# line plot
series.plot()
pyplot.show()
# Out:
# ------------------------------------------------------------
# TypeError                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in converter(*date_cols)
#    3020                 result = tools.to_datetime(
# -> 3021                     date_parser(*date_cols), errors='ignore')
#    3022                 if isinstance(result, datetime.datetime):
#
# <ipython-input-3-f32c6a9e2117> in parser(x)
#       6 def parser(x):
# ----> 7         return datetime.strptime('190'+x, '%Y-%m')
#       8 # series = read_csv('shampoo-sales.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
#
# TypeError: strptime() argument 1 must be str, not numpy.ndarray
#
# During handling of the above exception, another exception occurred:
#
# ValueError                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in converter(*date_cols)
#    3029                                                 parser=date_parser,
# -> 3030                                                 dayfirst=dayfirst),
#    3031                         errors='ignore')
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.try_parse_dates()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.try_parse_dates()
#
# <ipython-input-3-f32c6a9e2117> in parser(x)
#       6 def parser(x):
# ----> 7         return datetime.strptime('190'+x, '%Y-%m')
#       8 # series = read_csv('shampoo-sales.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
#
# ~/anaconda3/lib/python3.6/_strptime.py in _strptime_datetime(cls, data_string, format)
#     564     format string."""
# --> 565     tt, fraction = _strptime(data_string, format)
#     566     tzname, gmtoff = tt[-2:]
#
# ~/anaconda3/lib/python3.6/_strptime.py in _strptime(data_string, format)
#     361         raise ValueError("time data %r does not match format %r" %
# --> 362                          (data_string, format))
#     363     if len(data_string) != found.end():
#
# ValueError: time data '190Sales of shampoo over a three year period' does not match format '%Y-%m'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                 Traceback (most recent call last)
# <ipython-input-3-f32c6a9e2117> in <module>()
#       7         return datetime.strptime('190'+x, '%Y-%m')
#       8 # series = read_csv('shampoo-sales.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
# ----> 9 series = read_csv('/Users/lorinfields/Downloads/Shampoo-sales.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
#      10
#      11 # summarize first few rows
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     444
#     445     try:
# --> 446         data = parser.read(nrows)
#     447     finally:
#     448         parser.close()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1034                 raise ValueError('skipfooter not supported for iteration')
#    1035
# -> 1036         ret = self._engine.read(nrows)
#    1037
#    1038         # May alter columns / col_dict
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1920
#    1921             names, data = self._do_date_conversions(names, data)
# -> 1922             index, names = self._make_index(data, alldata, names)
#    1923
#    1924         # maybe create a mi on the columns
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _make_index(self, data, alldata, columns, indexnamerow)
#    1424         elif not self._has_complex_date_col:
#    1425             index = self._get_simple_index(alldata, columns)
# -> 1426             index = self._agg_index(index)
#    1427         elif self._has_complex_date_col:
#    1428             if not self._name_processed:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _agg_index(self, index, try_parse_dates)
#    1502
#    1503             if try_parse_dates and self._should_parse_dates(i):
# -> 1504                 arr = self._date_conv(arr)
#    1505
#    1506             if self.na_filter:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in converter(*date_cols)
#    3031                         errors='ignore')
#    3032                 except Exception:
# -> 3033                     return generic_parser(date_parser, *date_cols)
#    3034
#    3035     return converter
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/date_converters.py in generic_parser(parse_func, *cols)
#      37     for i in range(N):
#      38         args = [c[i] for c in cols]
# ---> 39         results[i] = parse_func(*args)
#      40
#      41     return results
#
# <ipython-input-3-f32c6a9e2117> in parser(x)
#       5 # load dataset
#       6 def parser(x):
# ----> 7         return datetime.strptime('190'+x, '%Y-%m')
#       8 # series = read_csv('shampoo-sales.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
#       9 series = read_csv('/Users/lorinfields/Downloads/Shampoo-sales.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
#
# ~/anaconda3/lib/python3.6/_strptime.py in _strptime_datetime(cls, data_string, format)
#     563     """Return a class cls instance based on the input string and the
#     564     format string."""
# --> 565     tt, fraction = _strptime(data_string, format)
#     566     tzname, gmtoff = tt[-2:]
#     567     args = tt[:6] + (fraction,)
#
# ~/anaconda3/lib/python3.6/_strptime.py in _strptime(data_string, format)
#     360     if not found:
#     361         raise ValueError("time data %r does not match format %r" %
# --> 362                          (data_string, format))
#     363     if len(data_string) != found.end():
#     364         raise ValueError("unconverted data remains: %s" %
#
# ValueError: time data '190Sales of shampoo over a three year period' does not match format '%Y-%m'
